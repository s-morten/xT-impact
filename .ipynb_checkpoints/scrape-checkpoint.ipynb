# %%
import soccerdata as sd

# %%
from pathlib import PosixPath


ws = sd.WhoScored(leagues="ENG-Premier League", seasons=[21], no_cache=False, no_store=False, data_dir=PosixPath('/home/morten/Develop/Open-Data/soccerdata'), path_to_browser='/usr/bin/chromium', headless=False)
# Out:
# [07/27/22 11:38:56] INFO     Saving cached data to /home/morten/Develop/Open-Data/soccerdata          ]8;id=505268;file:///home/morten/.conda/envs/LWP/lib/python3.9/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=414053;file:///home/morten/.conda/envs/LWP/lib/python3.9/site-packages/soccerdata/_common.py#89\89]8;;\
# [07/27/22 11:38:57] INFO     patching driver executable                                              ]8;id=250039;file:///home/morten/.conda/envs/LWP/lib/python3.9/site-packages/undetected_chromedriver/patcher.py\patcher.py]8;;\:]8;id=613085;file:///home/morten/.conda/envs/LWP/lib/python3.9/site-packages/undetected_chromedriver/patcher.py#231\231]8;;\
#                              /home/morten/.local/share/undetected_chromedriver/63190029ef66418b_chro
#                              medriver

# %%
ws.available_leagues()
# Out:
# ['ENG-Premier League',
#  'ESP-La Liga',
#  'FRA-Ligue 1',
#  'GER-Bundesliga',
#  'GER-Bundesliga2',
#  'ITA-Serie A']

# %%
buli_schedule = ws.read_schedule()
buli_schedule.head()
# Out:
# [07/27/22 11:39:22] INFO     Scraping game schedule from                                           ]8;id=686348;file:///home/morten/.conda/envs/LWP/lib/python3.9/site-packages/soccerdata/whoscored.py\whoscored.py]8;;\:]8;id=115130;file:///home/morten/.conda/envs/LWP/lib/python3.9/site-packages/soccerdata/whoscored.py#327\327]8;;\
#                              https://www.whoscored.com/Regions/252/Tournaments/2/Seasons/8618/Stag
#                              es/19793/Fixtures/England-Premier-League-2021-2022
# [07/27/22 11:39:27] INFO     Scraping game schedule for Sunday, May 1 2022                         ]8;id=451938;file:///home/morten/.conda/envs/LWP/lib/python3.9/site-packages/soccerdata/whoscored.py\whoscored.py]8;;\:]8;id=304030;file:///home/morten/.conda/envs/LWP/lib/python3.9/site-packages/soccerdata/whoscored.py#241\241]8;;\
# ...

# %%
events = ws.read_events()
events.head()
# Out:
# [07/27/22 11:42:00] INFO     Retrieving game schedule of ENG-Premier League - 2122 from the cache  ]8;id=173096;file:///home/morten/.conda/envs/LWP/lib/python3.9/site-packages/soccerdata/whoscored.py\whoscored.py]8;;\:]8;id=500566;file:///home/morten/.conda/envs/LWP/lib/python3.9/site-packages/soccerdata/whoscored.py#333\333]8;;\
#                     INFO     [1/380] Retrieving game with id=1549554                               ]8;id=916474;file:///home/morten/.conda/envs/LWP/lib/python3.9/site-packages/soccerdata/whoscored.py\whoscored.py]8;;\:]8;id=13075;file:///home/morten/.conda/envs/LWP/lib/python3.9/site-packages/soccerdata/whoscored.py#580\580]8;;\
# ...

# %%
# seasons downloaded: 
# italy_1 21, 
# germany_1 17, 18, 19, 20, 21, 
# germany_2 17, 18, 19, 20, 21,
# england_1 21
